# %% [markdown]
# <a href="https://colab.research.google.com/github/afeef2003/Credit-card-Fraud-Detection/blob/main/BegumFTD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***LETS BEGIN***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
datasets = pd.read_csv('/content/creditcard.csv')
datasets
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0        0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2        1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3        1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4        2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...    ...       ...       ...       ...       ...       ...       ...
# 5969  6634 -1.611463  0.190648  0.901715  1.531254 -1.535865  0.799245
# 5970  6635 -1.420272  1.449354  1.320110 -1.894320  0.913695  0.454601
# 5971  6637 -1.206696  0.284728  2.152053 -2.850437 -0.437285 -0.238376
# 5972  6644  1.067611  0.091006 -0.153917  0.704233  0.113894 -0.826866
# 5973  6645 -0.535272 -0.132299  2.180041  1.018303 -1.498819  0.529570
#
#             V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5974 entries, 0 to 5973
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5974 non-null   int64
#  1   V1      5974 non-null   float64
#  2   V2      5974 non-null   float64
#  3   V3      5974 non-null   float64
#  4   V4      5974 non-null   float64
#  5   V5      5974 non-null   float64
#  6   V6      5974 non-null   float64
#  7   V7      5974 non-null   float64
#  8   V8      5974 non-null   float64
#  9   V9      5974 non-null   float64
#  10  V10     5974 non-null   float64
#  11  V11     5974 non-null   float64
#  12  V12     5974 non-null   float64
#  13  V13     5974 non-null   float64
#  14  V14     5974 non-null   float64
#  15  V15     5974 non-null   float64
#  16  V16     5974 non-null   float64
#  17  V17     5974 non-null   float64
#  18  V18     5973 non-null   float64
#  19  V19     5973 non-null   float64
# ...

# %%
datasets.describe()
# Out:
#               Time           V1           V2           V3           V4  \
# count  5974.000000  5974.000000  5974.000000  5974.000000  5974.000000
# mean   2677.615501    -0.266159     0.285505     0.844231     0.104200
# std    1765.025532     1.395405     1.208867     1.031448     1.442339
# min       0.000000   -12.168192   -15.732974   -12.389545    -4.657545
# 25%    1162.250000    -1.015749    -0.280054     0.295701    -0.839417
# 50%    2537.000000    -0.420703     0.346083     0.882882     0.161767
# 75%    3781.750000     1.115402     0.941548     1.504158     1.071412
# max    6645.000000     1.685314     7.467017     4.101716     6.013346
#
#                 V5           V6           V7           V8           V9  ...  \
# count  5974.000000  5974.000000  5974.000000  5974.000000  5974.000000  ...
# mean      0.000709     0.194948     0.018324    -0.039006     0.396916  ...
# std       1.185900     1.365525     1.059870     1.304005     1.047749  ...
# ...

# %%
datasets['Class'].unique()
# Out:
# array([ 0.,  1., nan])

# %%
datasets['Class'].value_counts()
# Out:
# Class
# 0.0    5970
# 1.0       3
# Name: count, dtype: int64

# %%
datasets['Amount'].value_counts()
# Out:
# Amount
# 1.00      543
# 5.00      120
# 1.98      101
# 0.89       94
# 9.99       90
#          ...
# 174.27      1
# 888.62      1
# 189.80      1
# 288.28      1
# 139.90      1
# Name: count, Length: 2721, dtype: int64

# %%
datasets.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
datasets['Time'].describe()
# Out:
# count    5974.000000
# mean     2677.615501
# std      1765.025532
# min         0.000000
# 25%      1162.250000
# 50%      2537.000000
# 75%      3781.750000
# max      6645.000000
# Name: Time, dtype: float64

# %%
datasets['Amount'].describe()
# Out:
# count    5973.000000
# mean       65.061811
# std       192.490314
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.660000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
datasets['Time'].describe()
# Out:
# count    5974.000000
# mean     2677.615501
# std      1765.025532
# min         0.000000
# 25%      1162.250000
# 50%      2537.000000
# 75%      3781.750000
# max      6645.000000
# Name: Time, dtype: float64

# %%
plt.figure(figsize=(30,20))
sns.heatmap(datasets.corr(), cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %%
corr_matrix = datasets.corr()

# %%
corr_matrix
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# Time    1.000000 -0.000414  0.023605  0.027055  0.064945  0.041564  0.092181
# V1     -0.000414  1.000000 -0.204265 -0.195230  0.089013 -0.098441  0.018026
# V2      0.023605 -0.204265  1.000000  0.023919  0.039223  0.064890 -0.070527
# V3      0.027055 -0.195230  0.023919  1.000000  0.205319 -0.097368 -0.238108
# V4      0.064945  0.089013  0.039223  0.205319  1.000000 -0.145946  0.003967
# V5      0.041564 -0.098441  0.064890 -0.097368 -0.145946  1.000000  0.197355
# V6      0.092181  0.018026 -0.070527 -0.238108  0.003967  0.197355  1.000000
# V7     -0.105473 -0.113463  0.132811  0.031793 -0.009356 -0.165091 -0.109064
# V8      0.017927  0.216413 -0.191545  0.031948  0.036508  0.121139  0.020031
# V9      0.427499 -0.120341  0.026080  0.058498 -0.101747 -0.000708  0.029568
# V10    -0.120934 -0.121544  0.160206  0.021178  0.131960  0.013579  0.048836
# ...

# %%
low_corr_cols = [col for col in corr_matrix.columns if all(abs(corr_matrix[col]) < 0.13)]

# %%
datasets.drop(columns=low_corr_cols, inplace=True)

# %%
plt.figure(figsize=(30,20))
sns.heatmap(datasets.corr(), cmap='coolwarm', annot=True, fmt=".2f")
plt.show()

# %%
plt.figure(figsize=(15, 6))
ax = sns.heatmap(
    datasets.corr(),
    cmap='coolwarm',
    annot=True,
    fmt='.2f',
    annot_kws={"size": 10},  # Adjust annotation text size
    linewidths=0.5,  # Add lines between squares for better separation
    linecolor='black'  # Set the color of the lines
)
ax.set_title('Correlation Heatmap of Modified DataFrame', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
fig, ax = plt.subplots(3, 3, figsize=(20, 20))
ax = ax.flatten()
fig.suptitle('Box Plot to Check for Outliers', fontsize=24)
for i, column in enumerate(datasets.columns):
    if i >= 9:
        break
    sns.boxplot(data=datasets, x=column, ax=ax[i])
    ax[i].set_title(column, fontsize=18)
    ax[i].set_xlabel('')

# Adjust layout for better spacing
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %%
X = datasets.drop('Class', axis=1)
y = datasets['Class']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# ... (your previous code)

# Check for NaN values in 'y'
print(y.isnull().sum())

# Handle NaN values in 'y' (choose one method)
# 1. Remove rows with NaN values
y = y.dropna()
X = X.loc[y.index]  # Align X with the remaining y values

# 2. Impute missing values (replace with mean, median, etc.)
# y = y.fillna(y.mean())  # Replace with mean, for example

# Split the data after handling NaN values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
# Out:
# 1

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (4778, 30)
# (1195, 30)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-0.4552532 ,  1.06217746, -0.31561881, ..., -0.15652422,
#         -0.05008246, -0.29804904],
#        [ 0.56135233, -0.20480593,  0.06188988, ..., -0.26696776,
#         -0.88714448, -0.28261823],
#        [ 1.14800784, -0.35744951,  1.08740039, ...,  0.4881975 ,
#         -0.0124005 , -0.32006366],
#        ...,
#        [ 0.63829076,  0.64243341, -0.33664077, ..., -0.37775331,
#          0.25108119,  1.22425178],
#        [ 0.12065355, -0.21839938, -0.02361069, ..., -0.16655276,
#         -0.12223272, -0.20541275],
#        [ 1.29113594, -0.72402913,  0.94060974, ..., -0.06168349,
#          0.94112847, -0.32381849]])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
model = RandomForestClassifier(random_state=0)
model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
#undersampling
from collections import Counter
print(f'Original class distribution in y_train: {Counter(y_train)}')
# Out:
# Original class distribution in y_train: Counter({0.0: 4776, 1.0: 2})

# %%
from imblearn.under_sampling import RandomUnderSampler
undersampler = RandomUnderSampler(random_state=42)
X_train_resampled, y_train_resampled = undersampler.fit_resample(X_train, y_train)

# %%
print(f'Class distribution after undersampling: {Counter(y_train_resampled)}')
# Out:
# Class distribution after undersampling: Counter({0.0: 2, 1.0: 2})

# %%
model.fit(X_train_resampled, y_train_resampled)
y_pred = model.predict(X_test_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X_train_scaled)

# %%
#Generate new features based on existing ones, such as combining columns or creating new metrics
datasets['Amount_per_Time'] = datasets['Amount'] / (datasets['Time'] + 1)

# %%
#Apply log transformation to handle skewed data
datasets['Log_Amount'] = np.log1p(datasets['Amount'])

# %%
#Create new features by multiplying correlated columns and then assess their importance
datasets['V1_V2'] = datasets['V1'] * datasets['V2']
datasets['V3_V4'] = datasets['V3'] * datasets['V4']

# %%
#After creating new features, you may want to drop features that are no longer important or redundant.
datasets.drop(columns=['V1', 'V2'], inplace=True)

# %%
importances = model.feature_importances_
important_features = [feature for feature, importance in zip(X.columns, importances) if importance > 0.01]
X_important = X[important_features]

# %%
import pandas as pd

# Check the class distribution
print(pd.Series(y_train_resampled).value_counts())
# Out:
# Class
# 0.0    2
# 1.0    2
# Name: count, dtype: int64

# %%
import pandas as pd
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# Check the class distribution
print(pd.Series(y_train_resampled).value_counts())

# Adjust cross-validation strategy
# Use a lower number of splits or a different cross-validation strategy if classes are imbalanced
cv = StratifiedKFold(n_splits=2)  # Example: use 2 splits instead of 3

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20]
}
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=0),
                           param_grid=param_grid,
                           cv=cv)  # Use the adjusted cross-validation strategy
grid_search.fit(X_train_resampled, y_train_resampled)
best_model = grid_search.best_estimator_
# Out:
# Class
# 0.0    2
# 1.0    2
# Name: count, dtype: int64

# %%
prediction = model.predict(X_test_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ***THE END***
